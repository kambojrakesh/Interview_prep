# %%
import torch
import torch.nn as nn

# Define an embedding layer with vocabulary size 1000 and embedding dimension 200
embedding = nn.Embedding(1000, 200)

# Input tensor of shape (batch_size, sequence_length)
inputs = torch.LongTensor([[1, 2, 3], [4, 5, 6]])

# Pass the inputs through the embedding layer
embedded_inputs = embedding(inputs)

# The output tensor will have shape (batch_size, sequence_length, embedding_dim)
print(embedded_inputs.shape)
# Out:
# torch.Size([2, 3, 200])

# %%
embedded_inputs[0].shape
# Out:
# torch.Size([3, 200])

# %%
embedded_inputs[0]
# Out:
# tensor([[-2.0054e+00, -1.4026e+00,  7.9360e-01,  3.0933e-01, -1.1387e-02,
#          -8.6960e-01, -1.1035e+00, -4.2179e-01, -9.1248e-01, -2.3649e-01,
#          -1.2534e+00, -2.7396e-01, -1.0150e+00,  3.3127e-01, -8.2413e-01,
#           1.1087e+00,  7.2056e-01,  1.0086e+00,  4.8583e-01, -3.0095e-01,
#           1.3927e+00, -3.6457e-01, -8.0071e-02, -8.4046e-02,  3.1598e-01,
#          -4.6230e-01, -5.3331e-01, -4.8365e-01,  3.5405e-01, -8.6595e-01,
#          -4.2077e-01, -2.2869e-01,  2.5328e-01,  1.5447e+00,  1.3513e+00,
#           4.5193e-01, -5.6514e-01,  3.0528e-01,  2.9734e-01, -5.1859e-01,
#          -2.4050e-01, -1.0596e+00, -1.3054e-01, -1.3533e+00, -9.3549e-01,
#          -3.5528e-01,  8.2415e-01,  1.3514e+00,  2.6598e+00,  9.5829e-01,
#          -1.6543e+00, -1.5885e-01,  3.9971e-01,  1.3588e+00,  1.1133e+00,
#           3.3256e-01,  1.2826e+00, -6.8042e-01,  1.0918e+00, -1.9203e+00,
#           2.8615e-01,  8.9862e-01,  1.7479e+00,  1.4525e+00, -1.6354e-01,
# ...

# %%
embedding = nn.Embedding(num_embeddings=2, embedding_dim=3)
embedding.weight.data.uniform_(-0.1, 0.1)
# Out:
# tensor([[-0.0620, -0.0465, -0.0505],
#         [-0.0136,  0.0057,  0.0466]])
